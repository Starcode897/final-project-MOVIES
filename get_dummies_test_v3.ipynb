# %%
#Classifier takes integers and regressor takes floats
import pandas as pd
#import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB   
import statsmodels.api as sm
pd.set_option('display.max_columns', None)

# %%
path = "resources/telecom_cleaned.csv"
df = pd.read_csv(path)
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       Male              0     Yes        Yes      72          Yes
# 1     Female              0      No         No      44          Yes
# 2     Female              1     Yes         No      38          Yes
# 3       Male              0      No         No       4          Yes
# 4       Male              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 5971    Male              0     Yes         No       1          Yes
# 5972  Female              0     Yes        Yes      23          Yes
# 5973    Male              0     Yes        Yes      12          Yes
# 5974    Male              1      No         No      12          Yes
# 5975    Male              0      No         No      26          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0              Yes              No  No internet service  No internet service
# 1               No     Fiber optic                   No                  Yes
# 2              Yes     Fiber optic                   No                   No
# 3               No             DSL                   No                   No
# 4               No             DSL                  Yes                   No
# ...            ...             ...                  ...                  ...
# 5971            No     Fiber optic                  Yes                   No
# 5972           Yes             DSL                  Yes                  Yes
# 5973            No              No  No internet service  No internet service
# 5974           Yes     Fiber optic                   No                   No
# 5975            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 0     No internet service  No internet service  No internet service
# 1                     Yes                   No                  Yes
# 2                      No                   No                   No
# 3                      No                   No                   No
# 4                     Yes                   No                   No
# ...                   ...                  ...                  ...
# 5971                   No                   No                  Yes
# 5972                  Yes                  Yes                  Yes
# 5973  No internet service  No internet service  No internet service
# 5974                  Yes                   No                  Yes
# 5975  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 0     No internet service        Two year               No
# 1                      No  Month-to-month              Yes
# 2                      No  Month-to-month              Yes
# 3                     Yes  Month-to-month              Yes
# 4                      No  Month-to-month               No
# ...                   ...             ...              ...
# 5971                  Yes  Month-to-month              Yes
# 5972                  Yes        Two year              Yes
# 5973  No internet service  Month-to-month              Yes
# 5974                  Yes  Month-to-month              Yes
# 5975  No internet service        One year               No
#
#                   PaymentMethod  MonthlyCharges  TotalCharges
# 0       Credit card (automatic)           24.10       1734.65
# 1       Credit card (automatic)           88.15       3973.20
# 2     Bank transfer (automatic)           74.95       2869.85
# 3              Electronic check           55.90        238.50
# 4              Electronic check           53.45        119.50
# ...                         ...             ...           ...
# 5971           Electronic check           95.00         95.00
# 5972    Credit card (automatic)           91.10       2198.30
# 5973           Electronic check           21.15        306.05
# 5974           Electronic check           99.45       1200.15
# 5975    Credit card (automatic)           19.80        457.30
#
# [5976 rows x 19 columns]

# %%
#inverse_transform(y) <-- How to turn labels back
label = LabelEncoder()
df = pd.get_dummies(df)

# %%
#Correlation matrix
corrMatrix = df.corr()
corrMatrix
# Out:
#                                          SeniorCitizen    tenure  \
# SeniorCitizen                                 1.000000  0.004503
# tenure                                        0.004503  1.000000
# MonthlyCharges                                0.219009  0.255676
# TotalCharges                                  0.093160  0.827439
# gender_Female                                 0.007322 -0.003617
# gender_Male                                  -0.007322  0.003617
# Partner_No                                   -0.015346 -0.384269
# Partner_Yes                                   0.015346  0.384269
# Dependents_No                                 0.213563 -0.167677
# Dependents_Yes                               -0.213563  0.167677
# PhoneService_No                              -0.009231 -0.009668
# PhoneService_Yes                              0.009231  0.009668
# MultipleLines_No                             -0.126118 -0.330257
# MultipleLines_No phone service               -0.009231 -0.009668
# MultipleLines_Yes                             0.132937  0.339378
# InternetService_DSL                          -0.107680  0.009399
# InternetService_Fiber optic                   0.255842  0.025484
# InternetService_No                           -0.184457 -0.041666
# OnlineSecurity_No                             0.185434 -0.267053
# OnlineSecurity_No internet service           -0.184457 -0.041666
# OnlineSecurity_Yes                           -0.037475  0.333373
# OnlineBackup_No                               0.091739 -0.310462
# OnlineBackup_No internet service             -0.184457 -0.041666
# OnlineBackup_Yes                              0.063545  0.358826
# DeviceProtection_No                           0.093749 -0.314264
# DeviceProtection_No internet service         -0.184457 -0.041666
# DeviceProtection_Yes                          0.061556  0.364705
# TechSupport_No                                0.207006 -0.265411
# TechSupport_No internet service              -0.184457 -0.041666
# TechSupport_Yes                              -0.061090  0.330226
# StreamingTV_No                                0.052886 -0.248456
# StreamingTV_No internet service              -0.184457 -0.041666
# StreamingTV_Yes                               0.102486  0.285228
# StreamingMovies_No                            0.038746 -0.261314
# StreamingMovies_No internet service          -0.184457 -0.041666
# StreamingMovies_Yes                           0.116494  0.296686
# Contract_Month-to-month                       0.141155 -0.647753
# Contract_One year                            -0.041164  0.199273
# Contract_Two year                            -0.125103  0.564137
# PaperlessBilling_No                          -0.155442 -0.005278
# PaperlessBilling_Yes                          0.155442  0.005278
# PaymentMethod_Bank transfer (automatic)      -0.013321  0.229061
# PaymentMethod_Credit card (automatic)        -0.029141  0.236018
# PaymentMethod_Electronic check                0.170126 -0.202272
# PaymentMethod_Mailed check                   -0.149715 -0.230213
#
#                                          MonthlyCharges  TotalCharges  \
# SeniorCitizen                                  0.219009      0.093160
# tenure                                         0.255676      0.827439
# MonthlyCharges                                 1.000000      0.656534
# TotalCharges                                   0.656534      1.000000
# gender_Female                                  0.013417      0.003364
# gender_Male                                   -0.013417     -0.003364
# Partner_No                                    -0.105204     -0.322968
# Partner_Yes                                    0.105204      0.322968
# Dependents_No                                  0.113888     -0.065459
# Dependents_Yes                                -0.113888      0.065459
# PhoneService_No                               -0.251798     -0.116877
# PhoneService_Yes                               0.251798      0.116877
# MultipleLines_No                              -0.340016     -0.401150
# MultipleLines_No phone service                -0.251798     -0.116877
# MultipleLines_Yes                              0.495081      0.475556
# InternetService_DSL                           -0.162862     -0.056409
# InternetService_Fiber optic                    0.785723      0.365467
# InternetService_No                            -0.760743     -0.376236
# OnlineSecurity_No                              0.350910     -0.069169
# OnlineSecurity_No internet service            -0.760743     -0.376236
# OnlineSecurity_Yes                             0.303377      0.418603
# OnlineBackup_No                                0.202055     -0.176166
# OnlineBackup_No internet service              -0.760743     -0.376236
# OnlineBackup_Yes                               0.445442      0.507473
# DeviceProtection_No                            0.168858     -0.188635
# DeviceProtection_No internet service          -0.760743     -0.376236
# DeviceProtection_Yes                           0.481627      0.522803
# TechSupport_No                                 0.315169     -0.088151
# TechSupport_No internet service               -0.760743     -0.376236
# TechSupport_Yes                                0.341577      0.437855
# StreamingTV_No                                 0.013440     -0.198515
# StreamingTV_No internet service               -0.760743     -0.376236
# StreamingTV_Yes                                0.628666      0.517397
# StreamingMovies_No                             0.012344     -0.210658
# StreamingMovies_No internet service           -0.760743     -0.376236
# StreamingMovies_Yes                            0.628068      0.527628
# Contract_Month-to-month                        0.053261     -0.447572
# Contract_One year                              0.005839      0.168206
# Contract_Two year                             -0.067715      0.360508
# PaperlessBilling_No                           -0.355469     -0.162113
# PaperlessBilling_Yes                           0.355469      0.162113
# PaymentMethod_Bank transfer (automatic)        0.049261      0.179275
# PaymentMethod_Credit card (automatic)          0.027662      0.182723
# PaymentMethod_Electronic check                 0.269427     -0.054918
# PaymentMethod_Mailed check                    -0.379051     -0.294600
#
#                                          gender_Female  gender_Male  \
# SeniorCitizen                                 0.007322    -0.007322
# tenure                                       -0.003617     0.003617
# MonthlyCharges                                0.013417    -0.013417
# TotalCharges                                  0.003364    -0.003364
# gender_Female                                 1.000000    -1.000000
# gender_Male                                  -1.000000     1.000000
# Partner_No                                   -0.007460     0.007460
# Partner_Yes                                   0.007460    -0.007460
# Dependents_No                                 0.008643    -0.008643
# Dependents_Yes                               -0.008643     0.008643
# PhoneService_No                              -0.006170     0.006170
# PhoneService_Yes                              0.006170    -0.006170
# MultipleLines_No                              0.002105    -0.002105
# MultipleLines_No phone service               -0.006170     0.006170
# MultipleLines_Yes                             0.001590    -0.001590
# InternetService_DSL                          -0.008207     0.008207
# InternetService_Fiber optic                   0.010869    -0.010869
# InternetService_No                           -0.003633     0.003633
# OnlineSecurity_No                            -0.016105     0.016105
# OnlineSecurity_No internet service           -0.003633     0.003633
# OnlineSecurity_Yes                            0.021122    -0.021122
# OnlineBackup_No                              -0.014580     0.014580
# OnlineBackup_No internet service             -0.003633     0.003633
# OnlineBackup_Yes                              0.018296    -0.018296
# DeviceProtection_No                          -0.000519     0.000519
# DeviceProtection_No internet service         -0.003633     0.003633
# DeviceProtection_Yes                          0.003686    -0.003686
# TechSupport_No                               -0.005873     0.005873
# TechSupport_No internet service              -0.003633     0.003633
# TechSupport_Yes                               0.009761    -0.009761
# StreamingTV_No                               -0.005209     0.005209
# StreamingTV_No internet service              -0.003633     0.003633
# StreamingTV_Yes                               0.008309    -0.008309
# StreamingMovies_No                           -0.005104     0.005104
# StreamingMovies_No internet service          -0.003633     0.003633
# StreamingMovies_Yes                           0.008168    -0.008168
# Contract_Month-to-month                       0.004797    -0.004797
# Contract_One year                            -0.015975     0.015975
# Contract_Two year                             0.009739    -0.009739
# PaperlessBilling_No                          -0.013973     0.013973
# PaperlessBilling_Yes                          0.013973    -0.013973
# PaymentMethod_Bank transfer (automatic)       0.017203    -0.017203
# PaymentMethod_Credit card (automatic)        -0.002270     0.002270
# PaymentMethod_Electronic check               -0.007232     0.007232
# PaymentMethod_Mailed check                   -0.006573     0.006573
#
#                                          Partner_No  Partner_Yes  \
# SeniorCitizen                             -0.015346     0.015346
# tenure                                    -0.384269     0.384269
# MonthlyCharges                            -0.105204     0.105204
# TotalCharges                              -0.322968     0.322968
# gender_Female                             -0.007460     0.007460
# gender_Male                                0.007460    -0.007460
# Partner_No                                 1.000000    -1.000000
# Partner_Yes                               -1.000000     1.000000
# Dependents_No                              0.448684    -0.448684
# Dependents_Yes                            -0.448684     0.448684
# PhoneService_No                            0.025797    -0.025797
# PhoneService_Yes                          -0.025797     0.025797
# MultipleLines_No                           0.133240    -0.133240
# MultipleLines_No phone service             0.025797    -0.025797
# MultipleLines_Yes                         -0.150110     0.150110
# InternetService_DSL                        0.007904    -0.007904
# InternetService_Fiber optic               -0.006707     0.006707
# InternetService_No                        -0.001045     0.001045
# OnlineSecurity_No                          0.139352    -0.139352
# OnlineSecurity_No internet service        -0.001045     0.001045
# OnlineSecurity_Yes                        -0.153241     0.153241
# OnlineBackup_No                            0.145121    -0.145121
# OnlineBackup_No internet service          -0.001045     0.001045
# OnlineBackup_Yes                          -0.150043     0.150043
# DeviceProtection_No                        0.146907    -0.146907
# DeviceProtection_No internet service      -0.001045     0.001045
# DeviceProtection_Yes                      -0.152729     0.152729
# TechSupport_No                             0.115151    -0.115151
# TechSupport_No internet service           -0.001045     0.001045
# TechSupport_Yes                           -0.125955     0.125955
# StreamingTV_No                             0.130043    -0.130043
# StreamingTV_No internet service           -0.001045     0.001045
# StreamingTV_Yes                           -0.129998     0.129998
# StreamingMovies_No                         0.122175    -0.122175
# StreamingMovies_No internet service       -0.001045     0.001045
# StreamingMovies_Yes                       -0.121434     0.121434
# Contract_Month-to-month                    0.285318    -0.285318
# Contract_One year                         -0.084288     0.084288
# Contract_Two year                         -0.251833     0.251833
# PaperlessBilling_No                       -0.017177     0.017177
# PaperlessBilling_Yes                       0.017177    -0.017177
# PaymentMethod_Bank transfer (automatic)   -0.099743     0.099743
# PaymentMethod_Credit card (automatic)     -0.097370     0.097370
# PaymentMethod_Electronic check             0.086587    -0.086587
# PaymentMethod_Mailed check                 0.096607    -0.096607
#
#                                          Dependents_No  Dependents_Yes  \
# SeniorCitizen                                 0.213563       -0.213563
# tenure                                       -0.167677        0.167677
# MonthlyCharges                                0.113888       -0.113888
# TotalCharges                                 -0.065459        0.065459
# gender_Female                                 0.008643       -0.008643
# gender_Male                                  -0.008643        0.008643
# Partner_No                                    0.448684       -0.448684
# Partner_Yes                                  -0.448684        0.448684
# Dependents_No                                 1.000000       -1.000000
# Dependents_Yes                               -1.000000        1.000000
# PhoneService_No                               0.000294       -0.000294
# PhoneService_Yes                             -0.000294        0.000294
# MultipleLines_No                             -0.021767        0.021767
# MultipleLines_No phone service                0.000294       -0.000294
# MultipleLines_Yes                             0.021808       -0.021808
# InternetService_DSL                          -0.051455        0.051455
# InternetService_Fiber optic                   0.166520       -0.166520
# InternetService_No                           -0.141621        0.141621
# OnlineSecurity_No                             0.192958       -0.192958
# OnlineSecurity_No internet service           -0.141621        0.141621
# OnlineSecurity_Yes                           -0.084746        0.084746
# OnlineBackup_No                               0.138752       -0.138752
# OnlineBackup_No internet service             -0.141621        0.141621
# OnlineBackup_Yes                             -0.022271        0.022271
# DeviceProtection_No                           0.126343       -0.126343
# DeviceProtection_No internet service         -0.141621        0.141621
# DeviceProtection_Yes                         -0.009594        0.009594
# TechSupport_No                                0.177707       -0.177707
# TechSupport_No internet service              -0.141621        0.141621
# TechSupport_Yes                              -0.067592        0.067592
# StreamingTV_No                                0.100598       -0.100598
# StreamingTV_No internet service              -0.141621        0.141621
# StreamingTV_Yes                               0.018306       -0.018306
# StreamingMovies_No                            0.081810       -0.081810
# StreamingMovies_No internet service          -0.141621        0.141621
# StreamingMovies_Yes                           0.037320       -0.037320
# Contract_Month-to-month                       0.229486       -0.229486
# Contract_One year                            -0.063420        0.063420
# Contract_Two year                            -0.206752        0.206752
# PaperlessBilling_No                          -0.111229        0.111229
# PaperlessBilling_Yes                          0.111229       -0.111229
# PaymentMethod_Bank transfer (automatic)      -0.041413        0.041413
# PaymentMethod_Credit card (automatic)        -0.078852        0.078852
# PaymentMethod_Electronic check                0.156371       -0.156371
# PaymentMethod_Mailed check                   -0.057639        0.057639
#
#                                          PhoneService_No  PhoneService_Yes  \
# SeniorCitizen                                  -0.009231          0.009231
# tenure                                         -0.009668          0.009668
# MonthlyCharges                                 -0.251798          0.251798
# TotalCharges                                   -0.116877          0.116877
# gender_Female                                  -0.006170          0.006170
# gender_Male                                     0.006170         -0.006170
# Partner_No                                      0.025797         -0.025797
# Partner_Yes                                    -0.025797          0.025797
# Dependents_No                                   0.000294         -0.000294
# Dependents_Yes                                 -0.000294          0.000294
# PhoneService_No                                 1.000000         -1.000000
# PhoneService_Yes                               -1.000000          1.000000
# MultipleLines_No                               -0.314690          0.314690
# MultipleLines_No phone service                  1.000000         -1.000000
# MultipleLines_Yes                              -0.284517          0.284517
# InternetService_DSL                             0.454799         -0.454799
# InternetService_Fiber optic                    -0.292582          0.292582
# InternetService_No                             -0.172899          0.172899
# OnlineSecurity_No                               0.062464         -0.062464
# OnlineSecurity_No internet service             -0.172899          0.172899
# OnlineSecurity_Yes                              0.088082         -0.088082
# OnlineBackup_No                                 0.096062         -0.096062
# OnlineBackup_No internet service               -0.172899          0.172899
# OnlineBackup_Yes                                0.049087         -0.049087
# DeviceProtection_No                             0.075055         -0.075055
# DeviceProtection_No internet service           -0.172899          0.172899
# DeviceProtection_Yes                            0.071106         -0.071106
# TechSupport_No                                  0.061638         -0.061638
# TechSupport_No internet service                -0.172899          0.172899
# TechSupport_Yes                                 0.088645         -0.088645
# StreamingTV_No                                  0.123918         -0.123918
# StreamingTV_No internet service                -0.172899          0.172899
# StreamingTV_Yes                                 0.021240         -0.021240
# StreamingMovies_No                              0.114393         -0.114393
# StreamingMovies_No internet service            -0.172899          0.172899
# StreamingMovies_Yes                             0.031032         -0.031032
# Contract_Month-to-month                         0.002654         -0.002654
# Contract_One year                               0.006237         -0.006237
# Contract_Two year                              -0.009081          0.009081
# PaperlessBilling_No                             0.021517         -0.021517
# PaperlessBilling_Yes                           -0.021517          0.021517
# PaymentMethod_Bank transfer (automatic)        -0.011558          0.011558
# PaymentMethod_Credit card (automatic)           0.013462         -0.013462
# PaymentMethod_Electronic check                 -0.005208          0.005208
# PaymentMethod_Mailed check                      0.004002         -0.004002
#
#                                          MultipleLines_No  \
# SeniorCitizen                                   -0.126118
# tenure                                          -0.330257
# MonthlyCharges                                  -0.340016
# TotalCharges                                    -0.401150
# gender_Female                                    0.002105
# gender_Male                                     -0.002105
# Partner_No                                       0.133240
# Partner_Yes                                     -0.133240
# Dependents_No                                   -0.021767
# Dependents_Yes                                   0.021767
# PhoneService_No                                 -0.314690
# PhoneService_Yes                                 0.314690
# MultipleLines_No                                 1.000000
# MultipleLines_No phone service                  -0.314690
# MultipleLines_Yes                               -0.820430
# InternetService_DSL                             -0.068297
# InternetService_Fiber optic                     -0.192235
# InternetService_No                               0.311283
# OnlineSecurity_No                               -0.115026
# OnlineSecurity_No internet service               0.311283
# OnlineSecurity_Yes                              -0.155739
# OnlineBackup_No                                 -0.030285
# OnlineBackup_No internet service                 0.311283
# OnlineBackup_Yes                                -0.236763
# DeviceProtection_No                             -0.023257
# DeviceProtection_No internet service             0.311283
# DeviceProtection_Yes                            -0.245009
# TechSupport_No                                  -0.113059
# TechSupport_No internet service                  0.311283
# TechSupport_Yes                                 -0.157293
# StreamingTV_No                                   0.001328
# StreamingTV_No internet service                  0.311283
# StreamingTV_Yes                                 -0.264111
# StreamingMovies_No                               0.016180
# StreamingMovies_No internet service              0.311283
# StreamingMovies_Yes                             -0.278249
# Contract_Month-to-month                          0.088056
# Contract_One year                                0.002810
# Contract_Two year                               -0.105385
# PaperlessBilling_No                              0.154618
# PaperlessBilling_Yes                            -0.154618
# PaymentMethod_Bank transfer (automatic)         -0.068360
# PaymentMethod_Credit card (automatic)           -0.066079
# PaymentMethod_Electronic check                  -0.078282
# PaymentMethod_Mailed check                       0.220495
#
#                                          MultipleLines_No phone service  \
# SeniorCitizen                                                 -0.009231
# tenure                                                        -0.009668
# MonthlyCharges                                                -0.251798
# TotalCharges                                                  -0.116877
# gender_Female                                                 -0.006170
# gender_Male                                                    0.006170
# Partner_No                                                     0.025797
# Partner_Yes                                                   -0.025797
# Dependents_No                                                  0.000294
# Dependents_Yes                                                -0.000294
# PhoneService_No                                                1.000000
# PhoneService_Yes                                              -1.000000
# MultipleLines_No                                              -0.314690
# MultipleLines_No phone service                                 1.000000
# MultipleLines_Yes                                             -0.284517
# InternetService_DSL                                            0.454799
# InternetService_Fiber optic                                   -0.292582
# InternetService_No                                            -0.172899
# OnlineSecurity_No                                              0.062464
# OnlineSecurity_No internet service                            -0.172899
# OnlineSecurity_Yes                                             0.088082
# OnlineBackup_No                                                0.096062
# OnlineBackup_No internet service                              -0.172899
# OnlineBackup_Yes                                               0.049087
# DeviceProtection_No                                            0.075055
# DeviceProtection_No internet service                          -0.172899
# DeviceProtection_Yes                                           0.071106
# TechSupport_No                                                 0.061638
# TechSupport_No internet service                               -0.172899
# TechSupport_Yes                                                0.088645
# StreamingTV_No                                                 0.123918
# StreamingTV_No internet service                               -0.172899
# StreamingTV_Yes                                                0.021240
# StreamingMovies_No                                             0.114393
# StreamingMovies_No internet service                           -0.172899
# StreamingMovies_Yes                                            0.031032
# Contract_Month-to-month                                        0.002654
# Contract_One year                                              0.006237
# Contract_Two year                                             -0.009081
# PaperlessBilling_No                                            0.021517
# PaperlessBilling_Yes                                          -0.021517
# PaymentMethod_Bank transfer (automatic)                       -0.011558
# PaymentMethod_Credit card (automatic)                          0.013462
# PaymentMethod_Electronic check                                -0.005208
# PaymentMethod_Mailed check                                     0.004002
#
#                                          MultipleLines_Yes  \
# SeniorCitizen                                     0.132937
# tenure                                            0.339378
# MonthlyCharges                                    0.495081
# TotalCharges                                      0.475556
# gender_Female                                     0.001590
# gender_Male                                      -0.001590
# Partner_No                                       -0.150110
# Partner_Yes                                       0.150110
# Dependents_No                                     0.021808
# Dependents_Yes                                   -0.021808
# PhoneService_No                                  -0.284517
# PhoneService_Yes                                  0.284517
# MultipleLines_No                                 -0.820430
# MultipleLines_No phone service                   -0.284517
# MultipleLines_Yes                                 1.000000
# InternetService_DSL                              -0.204969
# InternetService_Fiber optic                       0.370390
# InternetService_No                               -0.210245
# OnlineSecurity_No                                 0.078549
# OnlineSecurity_No internet service               -0.210245
# OnlineSecurity_Yes                                0.104238
# OnlineBackup_No                                  -0.027276
# OnlineBackup_No internet service                 -0.210245
# OnlineBackup_Yes                                  0.209559
# DeviceProtection_No                              -0.021720
# DeviceProtection_No internet service             -0.210245
# DeviceProtection_Yes                              0.204625
# TechSupport_No                                    0.077060
# TechSupport_No internet service                  -0.210245
# TechSupport_Yes                                   0.105468
# StreamingTV_No                                   -0.075983
# StreamingTV_No internet service                  -0.210245
# StreamingTV_Yes                                   0.253954
# StreamingMovies_No                               -0.085246
# StreamingMovies_No internet service              -0.210245
# StreamingMovies_Yes                               0.262335
# Contract_Month-to-month                          -0.090534
# Contract_One year                                -0.006596
# Contract_Two year                                 0.111907
# PaperlessBilling_No                              -0.169122
# PaperlessBilling_Yes                              0.169122
# PaymentMethod_Bank transfer (automatic)           0.076004
# PaymentMethod_Credit card (automatic)             0.058630
# PaymentMethod_Electronic check                    0.082201
# PaymentMethod_Mailed check                       -0.225106
#
#                                          InternetService_DSL  \
# SeniorCitizen                                      -0.107680
# tenure                                              0.009399
# MonthlyCharges                                     -0.162862
# TotalCharges                                       -0.056409
# gender_Female                                      -0.008207
# gender_Male                                         0.008207
# Partner_No                                          0.007904
# Partner_Yes                                        -0.007904
# Dependents_No                                      -0.051455
# Dependents_Yes                                      0.051455
# PhoneService_No                                     0.454799
# PhoneService_Yes                                   -0.454799
# MultipleLines_No                                   -0.068297
# MultipleLines_No phone service                      0.454799
# MultipleLines_Yes                                  -0.204969
# InternetService_DSL                                 1.000000
# InternetService_Fiber optic                        -0.643321
# InternetService_No                                 -0.380167
# OnlineSecurity_No                                   0.029612
# OnlineSecurity_No internet service                 -0.380167
# OnlineSecurity_Yes                                  0.312876
# OnlineBackup_No                                     0.163682
# OnlineBackup_No internet service                   -0.380167
# OnlineBackup_Yes                                    0.157377
# DeviceProtection_No                                 0.174011
# DeviceProtection_No internet service               -0.380167
# DeviceProtection_Yes                                0.146952
# TechSupport_No                                      0.034501
# TechSupport_No internet service                    -0.380167
# TechSupport_Yes                                     0.306246
# StreamingTV_No                                      0.301925
# StreamingTV_No internet service                    -0.380167
# StreamingTV_Yes                                     0.017055
# StreamingMovies_No                                  0.287627
# StreamingMovies_No internet service                -0.380167
# StreamingMovies_Yes                                 0.032088
# Contract_Month-to-month                            -0.062251
# Contract_One year                                   0.045218
# Contract_Two year                                   0.029197
# PaperlessBilling_No                                 0.066162
# PaperlessBilling_Yes                               -0.066162
# PaymentMethod_Bank transfer (automatic)             0.024638
# PaymentMethod_Credit card (automatic)               0.050566
# PaymentMethod_Electronic check                     -0.104956
# PaymentMethod_Mailed check                          0.044120
#
#                                          InternetService_Fiber optic  \
# SeniorCitizen                                               0.255842
# tenure                                                      0.025484
# MonthlyCharges                                              0.785723
# TotalCharges                                                0.365467
# gender_Female                                               0.010869
# gender_Male                                                -0.010869
# Partner_No                                                 -0.006707
# Partner_Yes                                                 0.006707
# Dependents_No                                               0.166520
# Dependents_Yes                                             -0.166520
# PhoneService_No                                            -0.292582
# PhoneService_Yes                                            0.292582
# MultipleLines_No                                           -0.192235
# MultipleLines_No phone service                             -0.292582
# MultipleLines_Yes                                           0.370390
# InternetService_DSL                                        -0.643321
# InternetService_Fiber optic                                 1.000000
# InternetService_No                                         -0.463544
# OnlineSecurity_No                                           0.403989
# OnlineSecurity_No internet service                         -0.463544
# OnlineSecurity_Yes                                         -0.025563
# OnlineBackup_No                                             0.223900
# OnlineBackup_No internet service                           -0.463544
# OnlineBackup_Yes                                            0.166597
# DeviceProtection_No                                         0.218560
# DeviceProtection_No internet service                       -0.463544
# DeviceProtection_Yes                                        0.172505
# TechSupport_No                                              0.395990
# TechSupport_No internet service                            -0.463544
# TechSupport_Yes                                            -0.016626
# StreamingTV_No                                              0.064188
# StreamingTV_No internet service                            -0.463544
# StreamingTV_Yes                                             0.326707
# StreamingMovies_No                                          0.073587
# StreamingMovies_No internet service                        -0.463544
# StreamingMovies_Yes                                         0.316561
# Contract_Month-to-month                                     0.239064
# Contract_One year                                          -0.075283
# Contract_Two year                                          -0.206536
# PaperlessBilling_No                                        -0.329999
# PaperlessBilling_Yes                                        0.329999
# PaymentMethod_Bank transfer (automatic)                    -0.015588
# PaymentMethod_Credit card (automatic)                      -0.051738
# PaymentMethod_Electronic check                              0.333538
# PaymentMethod_Mailed check                                 -0.309204
#
#                                          InternetService_No  \
# SeniorCitizen                                     -0.184457
# tenure                                            -0.041666
# MonthlyCharges                                    -0.760743
# TotalCharges                                      -0.376236
# gender_Female                                     -0.003633
# gender_Male                                        0.003633
# Partner_No                                        -0.001045
# Partner_Yes                                        0.001045
# Dependents_No                                     -0.141621
# Dependents_Yes                                     0.141621
# PhoneService_No                                   -0.172899
# PhoneService_Yes                                   0.172899
# MultipleLines_No                                   0.311283
# MultipleLines_No phone service                    -0.172899
# MultipleLines_Yes                                 -0.210245
# InternetService_DSL                               -0.380167
# InternetService_Fiber optic                       -0.463544
# InternetService_No                                 1.000000
# OnlineSecurity_No                                 -0.522332
# OnlineSecurity_No internet service                 1.000000
# OnlineSecurity_Yes                                -0.331229
# OnlineBackup_No                                   -0.459934
# OnlineBackup_No internet service                   1.000000
# OnlineBackup_Yes                                  -0.383408
# DeviceProtection_No                               -0.465437
# DeviceProtection_No internet service               1.000000
# DeviceProtection_Yes                              -0.378480
# TechSupport_No                                    -0.518327
# TechSupport_No internet service                    1.000000
# TechSupport_Yes                                   -0.334353
# StreamingTV_No                                    -0.426982
# StreamingTV_No internet service                    1.000000
# StreamingTV_Yes                                   -0.414434
# StreamingMovies_No                                -0.421789
# StreamingMovies_No internet service                1.000000
# StreamingMovies_Yes                               -0.419575
# Contract_Month-to-month                           -0.216767
# Contract_One year                                  0.038616
# Contract_Two year                                  0.215725
# PaperlessBilling_No                                0.322100
# PaperlessBilling_Yes                              -0.322100
# PaymentMethod_Bank transfer (automatic)           -0.009683
# PaymentMethod_Credit card (automatic)              0.003981
# PaymentMethod_Electronic check                    -0.281476
# PaymentMethod_Mailed check                         0.322487
#
#                                          OnlineSecurity_No  \
# SeniorCitizen                                     0.185434
# tenure                                           -0.267053
# MonthlyCharges                                    0.350910
# TotalCharges                                     -0.069169
# gender_Female                                    -0.016105
# gender_Male                                       0.016105
# Partner_No                                        0.139352
# Partner_Yes                                      -0.139352
# Dependents_No                                     0.192958
# Dependents_Yes                                   -0.192958
# PhoneService_No                                   0.062464
# PhoneService_Yes                                 -0.062464
# MultipleLines_No                                 -0.115026
# MultipleLines_No phone service                    0.062464
# MultipleLines_Yes                                 0.078549
# InternetService_DSL                               0.029612
# InternetService_Fiber optic                       0.403989
# InternetService_No                               -0.522332
# OnlineSecurity_No                                 1.000000
# OnlineSecurity_No internet service               -0.522332
# OnlineSecurity_Yes                               -0.631593
# OnlineBackup_No                                   0.378382
# OnlineBackup_No internet service                 -0.522332
# OnlineBackup_Yes                                  0.056580
# DeviceProtection_No                               0.378865
# DeviceProtection_No internet service             -0.522332
# DeviceProtection_Yes                              0.055723
# TechSupport_No                                    0.468210
# TechSupport_No internet service                  -0.522332
# TechSupport_Yes                                  -0.042978
# StreamingTV_No                                    0.267427
# StreamingTV_No internet service                  -0.522332
# StreamingTV_Yes                                   0.171786
# StreamingMovies_No                                0.274588
# StreamingMovies_No internet service              -0.522332
# StreamingMovies_Yes                               0.164823
# Contract_Month-to-month                           0.401904
# Contract_One year                                -0.124352
# Contract_Two year                                -0.349340
# PaperlessBilling_No                              -0.261309
# PaperlessBilling_Yes                              0.261309
# PaymentMethod_Bank transfer (automatic)          -0.071824
# PaymentMethod_Credit card (automatic)            -0.105958
# PaymentMethod_Electronic check                    0.323892
# PaymentMethod_Mailed check                       -0.189587
#
#                                          OnlineSecurity_No internet service  \
# SeniorCitizen                                                     -0.184457
# tenure                                                            -0.041666
# MonthlyCharges                                                    -0.760743
# TotalCharges                                                      -0.376236
# gender_Female                                                     -0.003633
# gender_Male                                                        0.003633
# Partner_No                                                        -0.001045
# Partner_Yes                                                        0.001045
# Dependents_No                                                     -0.141621
# Dependents_Yes                                                     0.141621
# PhoneService_No                                                   -0.172899
# PhoneService_Yes                                                   0.172899
# MultipleLines_No                                                   0.311283
# MultipleLines_No phone service                                    -0.172899
# MultipleLines_Yes                                                 -0.210245
# InternetService_DSL                                               -0.380167
# InternetService_Fiber optic                                       -0.463544
# InternetService_No                                                 1.000000
# OnlineSecurity_No                                                 -0.522332
# OnlineSecurity_No internet service                                 1.000000
# OnlineSecurity_Yes                                                -0.331229
# OnlineBackup_No                                                   -0.459934
# OnlineBackup_No internet service                                   1.000000
# OnlineBackup_Yes                                                  -0.383408
# DeviceProtection_No                                               -0.465437
# DeviceProtection_No internet service                               1.000000
# DeviceProtection_Yes                                              -0.378480
# TechSupport_No                                                    -0.518327
# TechSupport_No internet service                                    1.000000
# TechSupport_Yes                                                   -0.334353
# StreamingTV_No                                                    -0.426982
# StreamingTV_No internet service                                    1.000000
# StreamingTV_Yes                                                   -0.414434
# StreamingMovies_No                                                -0.421789
# StreamingMovies_No internet service                                1.000000
# StreamingMovies_Yes                                               -0.419575
# Contract_Month-to-month                                           -0.216767
# Contract_One year                                                  0.038616
# Contract_Two year                                                  0.215725
# PaperlessBilling_No                                                0.322100
# PaperlessBilling_Yes                                              -0.322100
# PaymentMethod_Bank transfer (automatic)                           -0.009683
# PaymentMethod_Credit card (automatic)                              0.003981
# PaymentMethod_Electronic check                                    -0.281476
# PaymentMethod_Mailed check                                         0.322487
#
#                                          OnlineSecurity_Yes  OnlineBackup_No  \
# SeniorCitizen                                     -0.037475         0.091739
# tenure                                             0.333373        -0.310462
# MonthlyCharges                                     0.303377         0.202055
# TotalCharges                                       0.418603        -0.176166
# gender_Female                                      0.021122        -0.014580
# gender_Male                                       -0.021122         0.014580
# Partner_No                                        -0.153241         0.145121
# Partner_Yes                                        0.153241        -0.145121
# Dependents_No                                     -0.084746         0.138752
# Dependents_Yes                                     0.084746        -0.138752
# PhoneService_No                                    0.088082         0.096062
# PhoneService_Yes                                  -0.088082        -0.096062
# MultipleLines_No                                  -0.155739        -0.030285
# MultipleLines_No phone service                     0.088082         0.096062
# MultipleLines_Yes                                  0.104238        -0.027276
# InternetService_DSL                                0.312876         0.163682
# InternetService_Fiber optic                       -0.025563         0.223900
# InternetService_No                                -0.331229        -0.459934
# OnlineSecurity_No                                 -0.631593         0.378382
# OnlineSecurity_No internet service                -0.331229        -0.459934
# OnlineSecurity_Yes                                 1.000000        -0.000511
# OnlineBackup_No                                   -0.000511         1.000000
# OnlineBackup_No internet service                  -0.331229        -0.459934
# OnlineBackup_Yes                                   0.285984        -0.643753
# DeviceProtection_No                                0.003957         0.362953
# DeviceProtection_No internet service              -0.331229        -0.459934
# DeviceProtection_Yes                               0.282451         0.018376
# TechSupport_No                                    -0.046815         0.378414
# TechSupport_No internet service                   -0.331229        -0.459934
# TechSupport_Yes                                    0.351543        -0.000526
# StreamingTV_No                                     0.092300         0.315168
# StreamingTV_No internet service                   -0.331229        -0.459934
# StreamingTV_Yes                                    0.186718         0.071063
# StreamingMovies_No                                 0.079656         0.311995
# StreamingMovies_No internet service               -0.331229        -0.459934
# StreamingMovies_Yes                                0.199097         0.074843
# Contract_Month-to-month                           -0.247621         0.335960
# Contract_One year                                  0.102485        -0.109207
# Contract_Two year                                  0.190407        -0.286974
# PaperlessBilling_No                               -0.003712        -0.147518
# PaperlessBilling_Yes                               0.003712         0.147518
# ...
# OnlineSecurity_No internet service                  -0.322100
# OnlineSecurity_Yes                                   0.003712
# OnlineBackup_No                                      0.147518
# OnlineBackup_No internet service                    -0.322100
# OnlineBackup_Yes                                     0.124147
# DeviceProtection_No                                  0.166044
# DeviceProtection_No internet service                -0.322100
# DeviceProtection_Yes                                 0.105043
# TechSupport_No                                       0.231767
# TechSupport_No internet service                     -0.322100
# TechSupport_Yes                                      0.036267
# StreamingTV_No                                       0.046130
# StreamingTV_No internet service                     -0.322100
# StreamingTV_Yes                                      0.225478
# StreamingMovies_No                                   0.060623
# StreamingMovies_No internet service                 -0.322100
# StreamingMovies_Yes                                  0.210466
# Contract_Month-to-month                              0.174109
# Contract_One year                                   -0.053207
# Contract_Two year                                   -0.151975
# PaperlessBilling_No                                 -1.000000
# PaperlessBilling_Yes                                 1.000000
# PaymentMethod_Bank transfer (automatic)             -0.018405
# PaymentMethod_Credit card (automatic)               -0.019777
# PaymentMethod_Electronic check                       0.210183
# PaymentMethod_Mailed check                          -0.199015
#
#                                          PaymentMethod_Bank transfer (automatic)  \
# SeniorCitizen                                                          -0.013321
# tenure                                                                  0.229061
# MonthlyCharges                                                          0.049261
# TotalCharges                                                            0.179275
# gender_Female                                                           0.017203
# gender_Male                                                            -0.017203
# Partner_No                                                             -0.099743
# Partner_Yes                                                             0.099743
# Dependents_No                                                          -0.041413
# Dependents_Yes                                                          0.041413
# PhoneService_No                                                        -0.011558
# PhoneService_Yes                                                        0.011558
# MultipleLines_No                                                       -0.068360
# MultipleLines_No phone service                                         -0.011558
# MultipleLines_Yes                                                       0.076004
# InternetService_DSL                                                     0.024638
# InternetService_Fiber optic                                            -0.015588
# InternetService_No                                                     -0.009683
# OnlineSecurity_No                                                      -0.071824
# OnlineSecurity_No internet service                                     -0.009683
# OnlineSecurity_Yes                                                      0.088276
# OnlineBackup_No                                                        -0.071928
# OnlineBackup_No internet service                                       -0.009683
# OnlineBackup_Yes                                                        0.083158
# DeviceProtection_No                                                    -0.073167
# DeviceProtection_No internet service                                   -0.009683
# DeviceProtection_Yes                                                    0.084896
# TechSupport_No                                                         -0.079095
# TechSupport_No internet service                                        -0.009683
# TechSupport_Yes                                                         0.095935
# StreamingTV_No                                                         -0.038751
# StreamingTV_No internet service                                        -0.009683
# StreamingTV_Yes                                                         0.047175
# StreamingMovies_No                                                     -0.048257
# StreamingMovies_No internet service                                    -0.009683
# StreamingMovies_Yes                                                     0.056463
# Contract_Month-to-month                                                -0.166277
# Contract_One year                                                       0.053730
# Contract_Two year                                                       0.142339
# PaperlessBilling_No                                                     0.018405
# PaperlessBilling_Yes                                                   -0.018405
# PaymentMethod_Bank transfer (automatic)                                 1.000000
# PaymentMethod_Credit card (automatic)                                  -0.279109
# PaymentMethod_Electronic check                                         -0.375910
# PaymentMethod_Mailed check                                             -0.287318
#
#                                          PaymentMethod_Credit card (automatic)  \
# SeniorCitizen                                                        -0.029141
# tenure                                                                0.236018
# MonthlyCharges                                                        0.027662
# TotalCharges                                                          0.182723
# gender_Female                                                        -0.002270
# gender_Male                                                           0.002270
# Partner_No                                                           -0.097370
# Partner_Yes                                                           0.097370
# Dependents_No                                                        -0.078852
# Dependents_Yes                                                        0.078852
# PhoneService_No                                                       0.013462
# PhoneService_Yes                                                     -0.013462
# MultipleLines_No                                                     -0.066079
# MultipleLines_No phone service                                        0.013462
# MultipleLines_Yes                                                     0.058630
# InternetService_DSL                                                   0.050566
# InternetService_Fiber optic                                          -0.051738
# InternetService_No                                                    0.003981
# OnlineSecurity_No                                                    -0.105958
# OnlineSecurity_No internet service                                    0.003981
# OnlineSecurity_Yes                                                    0.113621
# OnlineBackup_No                                                      -0.089385
# OnlineBackup_No internet service                                      0.003981
# OnlineBackup_Yes                                                      0.089540
# DeviceProtection_No                                                  -0.118337
# DeviceProtection_No internet service                                  0.003981
# DeviceProtection_Yes                                                  0.120311
# TechSupport_No                                                       -0.110007
# TechSupport_No internet service                                       0.003981
# TechSupport_Yes                                                       0.117627
# StreamingTV_No                                                       -0.041609
# StreamingTV_No internet service                                       0.003981
# StreamingTV_Yes                                                       0.038516
# StreamingMovies_No                                                   -0.051152
# StreamingMovies_No internet service                                   0.003981
# StreamingMovies_Yes                                                   0.047858
# Contract_Month-to-month                                              -0.210282
# Contract_One year                                                     0.067497
# Contract_Two year                                                     0.180444
# PaperlessBilling_No                                                   0.019777
# PaperlessBilling_Yes                                                 -0.019777
# PaymentMethod_Bank transfer (automatic)                              -0.279109
# PaymentMethod_Credit card (automatic)                                 1.000000
# PaymentMethod_Electronic check                                       -0.375173
# PaymentMethod_Mailed check                                           -0.286755
#
#                                          PaymentMethod_Electronic check  \
# SeniorCitizen                                                  0.170126
# tenure                                                        -0.202272
# MonthlyCharges                                                 0.269427
# TotalCharges                                                  -0.054918
# gender_Female                                                 -0.007232
# gender_Male                                                    0.007232
# Partner_No                                                     0.086587
# Partner_Yes                                                   -0.086587
# Dependents_No                                                  0.156371
# Dependents_Yes                                                -0.156371
# PhoneService_No                                               -0.005208
# PhoneService_Yes                                               0.005208
# MultipleLines_No                                              -0.078282
# MultipleLines_No phone service                                -0.005208
# MultipleLines_Yes                                              0.082201
# InternetService_DSL                                           -0.104956
# InternetService_Fiber optic                                    0.333538
# InternetService_No                                            -0.281476
# OnlineSecurity_No                                              0.323892
# OnlineSecurity_No internet service                            -0.281476
# OnlineSecurity_Yes                                            -0.102469
# OnlineBackup_No                                                0.230041
# OnlineBackup_No internet service                              -0.281476
# OnlineBackup_Yes                                               0.003303
# DeviceProtection_No                                            0.243444
# DeviceProtection_No internet service                          -0.281476
# DeviceProtection_Yes                                          -0.011050
# TechSupport_No                                                 0.330087
# TechSupport_No internet service                               -0.281476
# TechSupport_Yes                                               -0.108874
# StreamingTV_No                                                 0.092895
# StreamingTV_No internet service                               -0.281476
# StreamingTV_Yes                                                0.144119
# StreamingMovies_No                                             0.103101
# StreamingMovies_No internet service                           -0.281476
# StreamingMovies_Yes                                            0.133740
# Contract_Month-to-month                                        0.327227
# Contract_One year                                             -0.113299
# Contract_Two year                                             -0.272862
# PaperlessBilling_No                                           -0.210183
# PaperlessBilling_Yes                                           0.210183
# PaymentMethod_Bank transfer (automatic)                       -0.375910
# PaymentMethod_Credit card (automatic)                         -0.375173
# PaymentMethod_Electronic check                                 1.000000
# PaymentMethod_Mailed check                                    -0.386207
#
#                                          PaymentMethod_Mailed check
# SeniorCitizen                                             -0.149715
# tenure                                                    -0.230213
# MonthlyCharges                                            -0.379051
# TotalCharges                                              -0.294600
# gender_Female                                             -0.006573
# gender_Male                                                0.006573
# Partner_No                                                 0.096607
# Partner_Yes                                               -0.096607
# Dependents_No                                             -0.057639
# Dependents_Yes                                             0.057639
# PhoneService_No                                            0.004002
# PhoneService_Yes                                          -0.004002
# MultipleLines_No                                           0.220495
# MultipleLines_No phone service                             0.004002
# MultipleLines_Yes                                         -0.225106
# InternetService_DSL                                        0.044120
# InternetService_Fiber optic                               -0.309204
# InternetService_No                                         0.322487
# OnlineSecurity_No                                         -0.189587
# OnlineSecurity_No internet service                         0.322487
# OnlineSecurity_Yes                                        -0.083423
# OnlineBackup_No                                           -0.100144
# OnlineBackup_No internet service                           0.322487
# OnlineBackup_Yes                                          -0.173755
# DeviceProtection_No                                       -0.085520
# DeviceProtection_No internet service                       0.322487
# DeviceProtection_Yes                                      -0.189589
# TechSupport_No                                            -0.185414
# TechSupport_No internet service                            0.322487
# TechSupport_Yes                                           -0.087701
# StreamingTV_No                                            -0.025453
# StreamingTV_No internet service                            0.322487
# StreamingTV_Yes                                           -0.246615
# StreamingMovies_No                                        -0.018188
# StreamingMovies_No internet service                        0.322487
# StreamingMovies_Yes                                       -0.253275
# Contract_Month-to-month                                    0.002370
# Contract_One year                                          0.008192
# Contract_Two year                                         -0.010625
# PaperlessBilling_No                                        0.199015
# PaperlessBilling_Yes                                      -0.199015
# PaymentMethod_Bank transfer (automatic)                   -0.287318
# PaymentMethod_Credit card (automatic)                     -0.286755
# PaymentMethod_Electronic check                            -0.386207
# PaymentMethod_Mailed check                                 1.000000

# %%
df_test=df[['SeniorCitizen', 'tenure', 'gender_Male', 'Partner_Yes', 'Dependents_Yes', 'PhoneService_Yes', 'MultipleLines_Yes'
           , 'InternetService_Fiber optic', 'OnlineSecurity_No', 'OnlineBackup_Yes',
           'DeviceProtection_Yes', 'TechSupport_Yes', 'StreamingTV_Yes',
           'StreamingMovies_Yes', 'Contract_Two year', 'PaperlessBilling_Yes']]
df_test
# Out:
#       SeniorCitizen  tenure  gender_Male  Partner_Yes  Dependents_Yes  \
# 0                 0      72            1            1               1
# 1                 0      44            0            0               0
# 2                 1      38            0            1               0
# 3                 0       4            1            0               0
# 4                 0       2            1            0               0
# ...             ...     ...          ...          ...             ...
# 5971              0       1            1            1               0
# 5972              0      23            0            1               1
# 5973              0      12            1            1               1
# 5974              1      12            1            0               0
# 5975              0      26            1            0               0
#
#       PhoneService_Yes  MultipleLines_Yes  InternetService_Fiber optic  \
# 0                    1                  1                            0
# 1                    1                  0                            1
# 2                    1                  1                            1
# 3                    1                  0                            0
# 4                    1                  0                            0
# ...                ...                ...                          ...
# 5971                 1                  0                            1
# 5972                 1                  1                            0
# 5973                 1                  0                            0
# 5974                 1                  1                            1
# 5975                 1                  0                            0
#
#       OnlineSecurity_No  OnlineBackup_Yes  DeviceProtection_Yes  \
# 0                     0                 0                     0
# 1                     1                 1                     1
# 2                     1                 0                     0
# 3                     1                 0                     0
# 4                     0                 0                     1
# ...                 ...               ...                   ...
# 5971                  0                 0                     0
# 5972                  0                 1                     1
# 5973                  0                 0                     0
# 5974                  1                 0                     1
# 5975                  0                 0                     0
#
#       TechSupport_Yes  StreamingTV_Yes  StreamingMovies_Yes  \
# 0                   0                0                    0
# 1                   0                1                    0
# 2                   0                0                    0
# 3                   0                0                    1
# 4                   0                0                    0
# ...               ...              ...                  ...
# 5971                0                1                    1
# 5972                1                1                    1
# 5973                0                0                    0
# 5974                0                1                    1
# 5975                0                0                    0
#
#       Contract_Two year  PaperlessBilling_Yes
# 0                     1                     0
# 1                     0                     1
# 2                     0                     1
# 3                     0                     1
# 4                     0                     0
# ...                 ...                   ...
# 5971                  0                     1
# 5972                  1                     1
# 5973                  0                     1
# 5974                  0                     1
# 5975                  0                     0
#
# [5976 rows x 16 columns]

# %%
corrMatrix = df_test.corr()
corrMatrix
# Out:
#                              SeniorCitizen    tenure  gender_Male  \
# SeniorCitizen                     1.000000  0.004503    -0.007322
# tenure                            0.004503  1.000000     0.003617
# gender_Male                      -0.007322  0.003617     1.000000
# Partner_Yes                       0.015346  0.384269    -0.007460
# Dependents_Yes                   -0.213563  0.167677     0.008643
# PhoneService_Yes                  0.009231  0.009668    -0.006170
# MultipleLines_Yes                 0.132937  0.339378    -0.001590
# InternetService_Fiber optic       0.255842  0.025484    -0.010869
# OnlineSecurity_No                 0.185434 -0.267053     0.016105
# OnlineBackup_Yes                  0.063545  0.358826    -0.018296
# DeviceProtection_Yes              0.061556  0.364705    -0.003686
# TechSupport_Yes                  -0.061090  0.330226    -0.009761
# StreamingTV_Yes                   0.102486  0.285228    -0.008309
# StreamingMovies_Yes               0.116494  0.296686    -0.008168
# Contract_Two year                -0.125103  0.564137    -0.009739
# PaperlessBilling_Yes              0.155442  0.005278    -0.013973
#
#                              Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# SeniorCitizen                   0.015346       -0.213563          0.009231
# tenure                          0.384269        0.167677          0.009668
# gender_Male                    -0.007460        0.008643         -0.006170
# Partner_Yes                     1.000000        0.448684          0.025797
# Dependents_Yes                  0.448684        1.000000          0.000294
# PhoneService_Yes                0.025797        0.000294          1.000000
# MultipleLines_Yes               0.150110       -0.021808          0.284517
# InternetService_Fiber optic     0.006707       -0.166520          0.292582
# OnlineSecurity_No              -0.139352       -0.192958         -0.062464
# OnlineBackup_Yes                0.150043        0.022271         -0.049087
# DeviceProtection_Yes            0.152729        0.009594         -0.071106
# TechSupport_Yes                 0.125955        0.067592         -0.088645
# StreamingTV_Yes                 0.129998       -0.018306         -0.021240
# StreamingMovies_Yes             0.121434       -0.037320         -0.031032
# Contract_Two year               0.251833        0.206752          0.009081
# PaperlessBilling_Yes           -0.017177       -0.111229          0.021517
#
#                              MultipleLines_Yes  InternetService_Fiber optic  \
# SeniorCitizen                         0.132937                     0.255842
# tenure                                0.339378                     0.025484
# gender_Male                          -0.001590                    -0.010869
# Partner_Yes                           0.150110                     0.006707
# Dependents_Yes                       -0.021808                    -0.166520
# PhoneService_Yes                      0.284517                     0.292582
# MultipleLines_Yes                     1.000000                     0.370390
# InternetService_Fiber optic           0.370390                     1.000000
# OnlineSecurity_No                     0.078549                     0.403989
# OnlineBackup_Yes                      0.209559                     0.166597
# DeviceProtection_Yes                  0.204625                     0.172505
# TechSupport_Yes                       0.105468                    -0.016626
# StreamingTV_Yes                       0.253954                     0.326707
# StreamingMovies_Yes                   0.262335                     0.316561
# Contract_Two year                     0.111907                    -0.206536
# PaperlessBilling_Yes                  0.169122                     0.329999
#
#                              OnlineSecurity_No  OnlineBackup_Yes  \
# SeniorCitizen                         0.185434          0.063545
# tenure                               -0.267053          0.358826
# gender_Male                           0.016105         -0.018296
# Partner_Yes                          -0.139352          0.150043
# Dependents_Yes                       -0.192958          0.022271
# PhoneService_Yes                     -0.062464         -0.049087
# MultipleLines_Yes                     0.078549          0.209559
# InternetService_Fiber optic           0.403989          0.166597
# OnlineSecurity_No                     1.000000          0.056580
# OnlineBackup_Yes                      0.056580          1.000000
# DeviceProtection_Yes                  0.055723          0.307059
# TechSupport_Yes                      -0.042978          0.288691
# StreamingTV_Yes                       0.171786          0.283243
# StreamingMovies_Yes                   0.164823          0.283742
# Contract_Two year                    -0.349340          0.112577
# PaperlessBilling_Yes                  0.261309          0.124147
#
#                              DeviceProtection_Yes  TechSupport_Yes  \
# SeniorCitizen                            0.061556        -0.061090
# tenure                                   0.364705         0.330226
# gender_Male                             -0.003686        -0.009761
# Partner_Yes                              0.152729         0.125955
# Dependents_Yes                           0.009594         0.067592
# PhoneService_Yes                        -0.071106        -0.088645
# MultipleLines_Yes                        0.204625         0.105468
# InternetService_Fiber optic              0.172505        -0.016626
# OnlineSecurity_No                        0.055723        -0.042978
# OnlineBackup_Yes                         0.307059         0.288691
# DeviceProtection_Yes                     1.000000         0.333452
# TechSupport_Yes                          0.333452         1.000000
# StreamingTV_Yes                          0.386823         0.282328
# StreamingMovies_Yes                      0.410298         0.285221
# Contract_Two year                        0.169486         0.241054
# PaperlessBilling_Yes                     0.105043         0.036267
#
#                              StreamingTV_Yes  StreamingMovies_Yes  \
# SeniorCitizen                       0.102486             0.116494
# tenure                              0.285228             0.296686
# gender_Male                        -0.008309            -0.008168
# Partner_Yes                         0.129998             0.121434
# Dependents_Yes                     -0.018306            -0.037320
# PhoneService_Yes                   -0.021240            -0.031032
# MultipleLines_Yes                   0.253954             0.262335
# InternetService_Fiber optic         0.326707             0.316561
# OnlineSecurity_No                   0.171786             0.164823
# OnlineBackup_Yes                    0.283243             0.283742
# DeviceProtection_Yes                0.386823             0.410298
# TechSupport_Yes                     0.282328             0.285221
# StreamingTV_Yes                     1.000000             0.534029
# StreamingMovies_Yes                 0.534029             1.000000
# Contract_Two year                   0.075832             0.080935
# PaperlessBilling_Yes                0.225478             0.210466
#
#                              Contract_Two year  PaperlessBilling_Yes
# SeniorCitizen                        -0.125103              0.155442
# tenure                                0.564137              0.005278
# gender_Male                          -0.009739             -0.013973
# Partner_Yes                           0.251833             -0.017177
# Dependents_Yes                        0.206752             -0.111229
# PhoneService_Yes                      0.009081              0.021517
# MultipleLines_Yes                     0.111907              0.169122
# InternetService_Fiber optic          -0.206536              0.329999
# OnlineSecurity_No                    -0.349340              0.261309
# OnlineBackup_Yes                      0.112577              0.124147
# DeviceProtection_Yes                  0.169486              0.105043
# TechSupport_Yes                       0.241054              0.036267
# StreamingTV_Yes                       0.075832              0.225478
# StreamingMovies_Yes                   0.080935              0.210466
# Contract_Two year                     1.000000             -0.151975
# PaperlessBilling_Yes                 -0.151975              1.000000

# %%
#Drop dependent columns
# df.drop(['MonthlyCharges', 'tenure', 'gender_Female', 'Partner_No', 'Dependents_No', 'PhoneService_No',
#             'PaperlessBilling_No']
# X = df.drop(['MonthlyCharges', 'tenure', 'gender_Female', 'Partner_No', 'Dependents_No', 'PhoneService_No',
#             'PaperlessBilling_No', 'MultipleLines_No', 'MultipleLines_No phone service', 'InternetService_No',
#             'InternetService_Fiber optic', 'OnlineSecurity_No', 'OnlineSecurity_No internet service', 'OnlineBackup_No', 
#             'OnlineBackup_No internet service', 'DeviceProtection_No', 'DeviceProtection_No internet service',
#             'TechSupport_No', 'TechSupport_No internet service', 'StreamingTV_No', 'StreamingTV_No internet service',
#             'StreamingMovies_No', 'StreamingMovies_No internet service', 'Contract_One year', 'Contract_Two year',
#             'PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'], axis=1)

X = df_test

y = df ["MonthlyCharges"]

X
# Out:
#       SeniorCitizen  tenure  gender_Male  Partner_Yes  Dependents_Yes  \
# 0                 0      72            1            1               1
# 1                 0      44            0            0               0
# 2                 1      38            0            1               0
# 3                 0       4            1            0               0
# 4                 0       2            1            0               0
# ...             ...     ...          ...          ...             ...
# 5971              0       1            1            1               0
# 5972              0      23            0            1               1
# 5973              0      12            1            1               1
# 5974              1      12            1            0               0
# 5975              0      26            1            0               0
#
#       PhoneService_Yes  MultipleLines_Yes  InternetService_Fiber optic  \
# 0                    1                  1                            0
# 1                    1                  0                            1
# 2                    1                  1                            1
# 3                    1                  0                            0
# 4                    1                  0                            0
# ...                ...                ...                          ...
# 5971                 1                  0                            1
# 5972                 1                  1                            0
# 5973                 1                  0                            0
# 5974                 1                  1                            1
# 5975                 1                  0                            0
#
#       OnlineSecurity_No  OnlineBackup_Yes  DeviceProtection_Yes  \
# 0                     0                 0                     0
# 1                     1                 1                     1
# 2                     1                 0                     0
# 3                     1                 0                     0
# 4                     0                 0                     1
# ...                 ...               ...                   ...
# 5971                  0                 0                     0
# 5972                  0                 1                     1
# 5973                  0                 0                     0
# 5974                  1                 0                     1
# 5975                  0                 0                     0
#
#       TechSupport_Yes  StreamingTV_Yes  StreamingMovies_Yes  \
# 0                   0                0                    0
# 1                   0                1                    0
# 2                   0                0                    0
# 3                   0                0                    1
# 4                   0                0                    0
# ...               ...              ...                  ...
# 5971                0                1                    1
# 5972                1                1                    1
# 5973                0                0                    0
# 5974                0                1                    1
# 5975                0                0                    0
#
#       Contract_Two year  PaperlessBilling_Yes
# 0                     1                     0
# 1                     0                     1
# 2                     0                     1
# 3                     0                     1
# 4                     0                     0
# ...                 ...                   ...
# 5971                  0                     1
# 5972                  1                     1
# 5973                  0                     1
# 5974                  0                     1
# 5975                  0                     0
#
# [5976 rows x 16 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#Rachel's code
model=LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9353409717997341
# Testing Score: 0.9334306015375897

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
# #DROPPING DeviceProtection_No internet service to test
# df3 = df2.drop(columns=['DeviceProtection_No internet service'])

# %%
def calculate_vif(df):
    vif_df = pd.DataFrame(columns = ['Var', 'Vif'])
    x_var_names = df.columns
    for i in range(0, x_var_names.shape[0]):
        y = df[x_var_names[i]]
        x = df[x_var_names.drop([x_var_names[i]])]
        r_squared = sm.OLS(y,x).fit().rsquared
        vif = round(1/(1-r_squared),2)
        vif_df.loc[i] = [x_var_names[i], vif]
    return vif_df.sort_values(by = 'Vif', axis = 0, ascending=False, inplace=False)

# X=df.drop(['Salary'],axis=1)
calculate_vif(X)
# Out:
#                             Var   Vif
# 1                        tenure  5.80
# 0                 SeniorCitizen  1.36
# 12              StreamingTV_Yes  0.29
# 4                Dependents_Yes  0.27
# 6             MultipleLines_Yes  0.23
# 14            Contract_Two year  0.23
# 11              TechSupport_Yes  0.21
# 15         PaperlessBilling_Yes  0.15
# 2                   gender_Male  0.14
# 8             OnlineSecurity_No  0.14
# 3                   Partner_Yes  0.08
# 7   InternetService_Fiber optic  0.08
# 9              OnlineBackup_Yes  0.04
# 13          StreamingMovies_Yes  0.04
# 5              PhoneService_Yes  0.01
# 10         DeviceProtection_Yes  0.00

# %%
sc =  StandardScaler()
X_scaler = sc.fit(X_train)
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

X_train
# Out:
# array([[-0.44181444,  1.56933913,  0.97618706, ...,  1.24653366,
#         -0.55793651,  0.82877312],
#        [-0.44181444, -1.29048487, -1.02439383, ..., -0.80222463,
#         -0.55793651, -1.20660284],
#        [-0.44181444,  1.61019376,  0.97618706, ...,  1.24653366,
#          1.79231861, -1.20660284],
#        ...,
#        [-0.44181444,  1.40592062,  0.97618706, ...,  1.24653366,
#          1.79231861, -1.20660284],
#        [-0.44181444,  0.79310119,  0.97618706, ...,  1.24653366,
#          1.79231861,  0.82877312],
#        [-0.44181444,  1.61019376, -1.02439383, ...,  1.24653366,
#          1.79231861,  0.82877312]])

# %% [markdown]
# # Linear Regression

# %%
line = LinearRegression()
line.fit(X_train, y_train)


pred_line = line.predict(X_train)
mse = mean_squared_error(y_train, pred_line)
r2 = r2_score(y_train, pred_line)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 58.67718346693112
# R-squared (R2 ): 0.9353409717997341

# %%
line.score(X_test, y_test)
# Out:
# 0.9334306015375897
